# %% [markdown]
# # Information Retrieval
#
# Let's download the classical data set, i.e. the CRANFIELD text set on aeronautics

# %%
! wget -q http://ir.dcs.gla.ac.uk/resources/test_collections/cran/cran.tar.gz
! tar -xvf cran.tar.gz
! rm cran.tar.gz*
# Out:
# zsh:1: command not found: wget
# tar: Error opening archive: Failed to open 'cran.tar.gz'
# zsh:1: no matches found: cran.tar.gz*

# %% [markdown]
# We take queries only (we will consider queries as documents)

# %%
! grep -v "^\." cran.qry > just.qry
! head -3 just.qry
# Out:
# grep: cran.qry: No such file or directory

# %% [markdown]
# We combine  multi-string queries into one

# %%
raw_query_data = [line.strip() for line in open("just.qry", "r").readlines()]
query_data = [""]

for query_part in raw_query_data:
  query_data[-1] += query_part + " "
  if query_part.endswith("."):
    query_data.append("")

query_data[:2] #Let's output the couple of documents as an example
# Out:
# ['']

# %% [markdown]
# ### Let's make queries to our documents

# %%
QUERIES = ['theory of bending', 'aeroelastic effects']

# %% [markdown]
# ## Boolean retrieval
# Let's represent each document as a "bitmask": that is a vector with a dimensionality equal to the vocabulary size, which has 1 at every position if the document contains the corresponding term; and 0 if it does not

# %%
# in different versions the answer could also differ, therefore it's important to have the same version
! pip install -q scikit-learn==0.22.2.post1
# Out:
#   ERROR: Command errored out with exit status 1:
#    command: /Users/ipsadm/opt/anaconda3/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/x0/50gt0r5j31xgwlz771y2q_340000gp/T/pip-install-fjvv8j34/scikit-learn_3debc9675a89421188c35cad03f9b911/setup.py'"'"'; __file__='"'"'/private/var/folders/x0/50gt0r5j31xgwlz771y2q_340000gp/T/pip-install-fjvv8j34/scikit-learn_3debc9675a89421188c35cad03f9b911/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/x0/50gt0r5j31xgwlz771y2q_340000gp/T/pip-wheel-_qk9k0ie
#        cwd: /private/var/folders/x0/50gt0r5j31xgwlz771y2q_340000gp/T/pip-install-fjvv8j34/scikit-learn_3debc9675a89421188c35cad03f9b911/
#   Complete output (1191 lines):
#   Partial import of sklearn during the build process.
#   C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64 -I/Users/ipsadm/opt/anaconda3/include -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64
#
#   compile options: '-c'
#   clang: test_program.c
#   clang -arch x86_64 objects/test_program.o -o test_program
#   C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64 -I/Users/ipsadm/opt/anaconda3/include -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64
#
#   compile options: '-c'
#   extra options: '-fopenmp'
#   clang: test_program.c
#   clang: error: unsupported option '-fopenmp'
#   /private/var/folders/x0/50gt0r5j31xgwlz771y2q_340000gp/T/pip-install-fjvv8j34/scikit-learn_3debc9675a89421188c35cad03f9b911/sklearn/_build_utils/openmp_helpers.py:112: UserWarning:
#
#                   ***********
#                   * WARNING *
#                   ***********
#
#   It seems that scikit-learn cannot be built with OpenMP.
#
#   - Make sure you have followed the installation instructions:
#
#       https://scikit-learn.org/dev/developers/advanced_installation.html
#
#   - If your compiler supports OpenMP but you still see this
#     message, please submit a bug report at:
#
#       https://github.com/scikit-learn/scikit-learn/issues
#
#   - The build will continue with OpenMP-based parallelism
#     disabled. Note however that some estimators will run in
#     sequential mode instead of leveraging thread-based
#     parallelism.
#
#                       ***
#
#     warnings.warn(message)
#   Compiling sklearn/__check_build/_check_build.pyx because it changed.
#   Compiling sklearn/preprocessing/_csr_polynomial_expansion.pyx because it changed.
#   Compiling sklearn/cluster/_dbscan_inner.pyx because it changed.
#   Compiling sklearn/cluster/_hierarchical_fast.pyx because it changed.
#   Compiling sklearn/cluster/_k_means_elkan.pyx because it changed.
#   Compiling sklearn/cluster/_k_means_fast.pyx because it changed.
#   Compiling sklearn/datasets/_svmlight_format_fast.pyx because it changed.
#   Compiling sklearn/decomposition/_online_lda_fast.pyx because it changed.
#   Compiling sklearn/decomposition/_cdnmf_fast.pyx because it changed.
#   Compiling sklearn/ensemble/_gradient_boosting.pyx because it changed.
#   Compiling sklearn/ensemble/_hist_gradient_boosting/_gradient_boosting.pyx because it changed.
#   Compiling sklearn/ensemble/_hist_gradient_boosting/histogram.pyx because it changed.
#   Compiling sklearn/ensemble/_hist_gradient_boosting/splitting.pyx because it changed.
#   Compiling sklearn/ensemble/_hist_gradient_boosting/_binning.pyx because it changed.
#   Compiling sklearn/ensemble/_hist_gradient_boosting/_predictor.pyx because it changed.
#   Compiling sklearn/ensemble/_hist_gradient_boosting/_loss.pyx because it changed.
#   Compiling sklearn/ensemble/_hist_gradient_boosting/common.pyx because it changed.
#   Compiling sklearn/ensemble/_hist_gradient_boosting/utils.pyx because it changed.
#   Compiling sklearn/feature_extraction/_hashing_fast.pyx because it changed.
#   Compiling sklearn/manifold/_utils.pyx because it changed.
#   Compiling sklearn/manifold/_barnes_hut_tsne.pyx because it changed.
#   Compiling sklearn/metrics/cluster/_expected_mutual_info_fast.pyx because it changed.
#   Compiling sklearn/metrics/_pairwise_fast.pyx because it changed.
#   Compiling sklearn/neighbors/_ball_tree.pyx because it changed.
#   Compiling sklearn/neighbors/_kd_tree.pyx because it changed.
#   Compiling sklearn/neighbors/_dist_metrics.pyx because it changed.
#   Compiling sklearn/neighbors/_typedefs.pyx because it changed.
#   Compiling sklearn/neighbors/_quad_tree.pyx because it changed.
#   Compiling sklearn/tree/_tree.pyx because it changed.
#   Compiling sklearn/tree/_splitter.pyx because it changed.
#   Compiling sklearn/tree/_criterion.pyx because it changed.
#   Compiling sklearn/tree/_utils.pyx because it changed.
#   Compiling sklearn/utils/sparsefuncs_fast.pyx because it changed.
#   Compiling sklearn/utils/_cython_blas.pyx because it changed.
#   Compiling sklearn/utils/arrayfuncs.pyx because it changed.
#   Compiling sklearn/utils/murmurhash.pyx because it changed.
#   Compiling sklearn/utils/graph_shortest_path.pyx because it changed.
#   Compiling sklearn/utils/_fast_dict.pyx because it changed.
#   Compiling sklearn/utils/_openmp_helpers.pyx because it changed.
#   Compiling sklearn/utils/_seq_dataset.pyx because it changed.
#   Compiling sklearn/utils/_weight_vector.pyx because it changed.
#   Compiling sklearn/utils/_random.pyx because it changed.
#   Compiling sklearn/utils/_logistic_sigmoid.pyx because it changed.
#   Compiling sklearn/svm/_libsvm.pyx because it changed.
#   Compiling sklearn/svm/_liblinear.pyx because it changed.
#   Compiling sklearn/svm/_libsvm_sparse.pyx because it changed.
#   Compiling sklearn/linear_model/_cd_fast.pyx because it changed.
#   Compiling sklearn/linear_model/_sgd_fast.pyx because it changed.
#   Compiling sklearn/linear_model/_sag_fast.pyx because it changed.
#   Compiling sklearn/_isotonic.pyx because it changed.
#   Partial import of sklearn during the build process.
#   Partial import of sklearn during the build process.
#   Partial import of sklearn during the build process.
#   Partial import of sklearn during the build process.
#   Partial import of sklearn during the build process.
#   Partial import of sklearn during the build process.
#   [ 5/50] Cythonizing sklearn/cluster/_k_means_elkan.pyx
#   [15/50] Cythonizing sklearn/ensemble/_hist_gradient_boosting/common.pyx
#   [16/50] Cythonizing sklearn/ensemble/_hist_gradient_boosting/histogram.pyx
#   [23/50] Cythonizing sklearn/manifold/_barnes_hut_tsne.pyx
#   [29/50] Cythonizing sklearn/neighbors/_kd_tree.pyx
#   [41/50] Cythonizing sklearn/utils/_fast_dict.pyx
#   [48/50] Cythonizing sklearn/utils/graph_shortest_path.pyx
#   [ 2/50] Cythonizing sklearn/_isotonic.pyx
#   [12/50] Cythonizing sklearn/ensemble/_hist_gradient_boosting/_gradient_boosting.pyx
#   [19/50] Cythonizing sklearn/feature_extraction/_hashing_fast.pyx
#   [22/50] Cythonizing sklearn/linear_model/_sgd_fast.pyx
#   [30/50] Cythonizing sklearn/neighbors/_quad_tree.pyx
#   [40/50] Cythonizing sklearn/utils/_cython_blas.pyx
#   [49/50] Cythonizing sklearn/utils/murmurhash.pyx
#   [ 1/50] Cythonizing sklearn/__check_build/_check_build.pyx
#   [ 7/50] Cythonizing sklearn/datasets/_svmlight_format_fast.pyx
#   [ 9/50] Cythonizing sklearn/decomposition/_online_lda_fast.pyx
#   [10/50] Cythonizing sklearn/ensemble/_gradient_boosting.pyx
#   [17/50] Cythonizing sklearn/ensemble/_hist_gradient_boosting/splitting.pyx
#   [26/50] Cythonizing sklearn/metrics/cluster/_expected_mutual_info_fast.pyx
#   [28/50] Cythonizing sklearn/neighbors/_dist_metrics.pyx
#   [34/50] Cythonizing sklearn/svm/_libsvm.pyx
#   [37/50] Cythonizing sklearn/tree/_splitter.pyx
#   [43/50] Cythonizing sklearn/utils/_openmp_helpers.pyx
#   [44/50] Cythonizing sklearn/utils/_random.pyx
#   [47/50] Cythonizing sklearn/utils/arrayfuncs.pyx
#   [ 3/50] Cythonizing sklearn/cluster/_dbscan_inner.pyx
#   [ 8/50] Cythonizing sklearn/decomposition/_cdnmf_fast.pyx
#   [11/50] Cythonizing sklearn/ensemble/_hist_gradient_boosting/_binning.pyx
#   [18/50] Cythonizing sklearn/ensemble/_hist_gradient_boosting/utils.pyx
#   [27/50] Cythonizing sklearn/neighbors/_ball_tree.pyx
#   [36/50] Cythonizing sklearn/tree/_criterion.pyx
#   [42/50] Cythonizing sklearn/utils/_logistic_sigmoid.pyx
#   [ 6/50] Cythonizing sklearn/cluster/_k_means_fast.pyx
#   [13/50] Cythonizing sklearn/ensemble/_hist_gradient_boosting/_loss.pyx
#   [21/50] Cythonizing sklearn/linear_model/_sag_fast.pyx
#   [24/50] Cythonizing sklearn/manifold/_utils.pyx
#   [25/50] Cythonizing sklearn/metrics/_pairwise_fast.pyx
#   [31/50] Cythonizing sklearn/neighbors/_typedefs.pyx
#   [33/50] Cythonizing sklearn/svm/_liblinear.pyx
#   [35/50] Cythonizing sklearn/svm/_libsvm_sparse.pyx
#   [38/50] Cythonizing sklearn/tree/_tree.pyx
#   [46/50] Cythonizing sklearn/utils/_weight_vector.pyx
#   [ 4/50] Cythonizing sklearn/cluster/_hierarchical_fast.pyx
#   [14/50] Cythonizing sklearn/ensemble/_hist_gradient_boosting/_predictor.pyx
#   [20/50] Cythonizing sklearn/linear_model/_cd_fast.pyx
#   [32/50] Cythonizing sklearn/preprocessing/_csr_polynomial_expansion.pyx
#   [39/50] Cythonizing sklearn/tree/_utils.pyx
#   [45/50] Cythonizing sklearn/utils/_seq_dataset.pyx
#   [50/50] Cythonizing sklearn/utils/sparsefuncs_fast.pyx
#   running bdist_wheel
#   running build
#   running config_cc
#   unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   build_src
#   building library "libsvm-skl" sources
#   building extension "sklearn.__check_build._check_build" sources
#   building extension "sklearn.preprocessing._csr_polynomial_expansion" sources
#   building extension "sklearn.cluster._dbscan_inner" sources
#   building extension "sklearn.cluster._hierarchical_fast" sources
#   building extension "sklearn.cluster._k_means_elkan" sources
#   building extension "sklearn.cluster._k_means_fast" sources
#   building extension "sklearn.datasets._svmlight_format_fast" sources
#   building extension "sklearn.decomposition._online_lda_fast" sources
#   building extension "sklearn.decomposition._cdnmf_fast" sources
#   building extension "sklearn.ensemble._gradient_boosting" sources
#   building extension "sklearn.ensemble._hist_gradient_boosting._gradient_boosting" sources
#   building extension "sklearn.ensemble._hist_gradient_boosting.histogram" sources
#   building extension "sklearn.ensemble._hist_gradient_boosting.splitting" sources
#   building extension "sklearn.ensemble._hist_gradient_boosting._binning" sources
#   building extension "sklearn.ensemble._hist_gradient_boosting._predictor" sources
#   building extension "sklearn.ensemble._hist_gradient_boosting._loss" sources
#   building extension "sklearn.ensemble._hist_gradient_boosting.common" sources
#   building extension "sklearn.ensemble._hist_gradient_boosting.utils" sources
#   building extension "sklearn.feature_extraction._hashing_fast" sources
#   building extension "sklearn.manifold._utils" sources
#   building extension "sklearn.manifold._barnes_hut_tsne" sources
#   building extension "sklearn.metrics.cluster._expected_mutual_info_fast" sources
#   building extension "sklearn.metrics._pairwise_fast" sources
#   building extension "sklearn.neighbors._ball_tree" sources
#   building extension "sklearn.neighbors._kd_tree" sources
#   building extension "sklearn.neighbors._dist_metrics" sources
#   building extension "sklearn.neighbors._typedefs" sources
#   building extension "sklearn.neighbors._quad_tree" sources
#   building extension "sklearn.tree._tree" sources
#   building extension "sklearn.tree._splitter" sources
#   building extension "sklearn.tree._criterion" sources
#   building extension "sklearn.tree._utils" sources
#   building extension "sklearn.utils.sparsefuncs_fast" sources
#   building extension "sklearn.utils._cython_blas" sources
#   building extension "sklearn.utils.arrayfuncs" sources
#   building extension "sklearn.utils.murmurhash" sources
#   building extension "sklearn.utils.graph_shortest_path" sources
#   building extension "sklearn.utils._fast_dict" sources
#   building extension "sklearn.utils._openmp_helpers" sources
#   building extension "sklearn.utils._seq_dataset" sources
#   building extension "sklearn.utils._weight_vector" sources
#   building extension "sklearn.utils._random" sources
#   building extension "sklearn.utils._logistic_sigmoid" sources
#   building extension "sklearn.svm._libsvm" sources
#   building extension "sklearn.svm._liblinear" sources
#   building extension "sklearn.svm._libsvm_sparse" sources
#   building extension "sklearn.linear_model._cd_fast" sources
#   building extension "sklearn.linear_model._sgd_fast" sources
#   building extension "sklearn.linear_model._sag_fast" sources
#   building extension "sklearn._isotonic" sources
#   building data_files sources
#   build_src: building npy-pkg config files
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-x86_64-3.9
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn
#   copying sklearn/conftest.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn
#   copying sklearn/multiclass.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn
#   copying sklearn/kernel_approximation.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn
#   copying sklearn/random_projection.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn
#   copying sklearn/isotonic.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn
#   copying sklearn/multioutput.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn
#   copying sklearn/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn
#   copying sklearn/kernel_ridge.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn
#   copying sklearn/_distributor_init.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn
#   copying sklearn/naive_bayes.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn
#   copying sklearn/setup.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn
#   copying sklearn/pipeline.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn
#   copying sklearn/discriminant_analysis.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn
#   copying sklearn/exceptions.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn
#   copying sklearn/_config.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn
#   copying sklearn/dummy.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn
#   copying sklearn/base.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn
#   copying sklearn/calibration.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/__check_build
#   copying sklearn/__check_build/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/__check_build
#   copying sklearn/__check_build/setup.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/__check_build
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/_build_utils
#   copying sklearn/_build_utils/deprecated_modules.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/_build_utils
#   copying sklearn/_build_utils/openmp_helpers.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/_build_utils
#   copying sklearn/_build_utils/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/_build_utils
#   copying sklearn/_build_utils/pre_build_helpers.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/_build_utils
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/compose
#   copying sklearn/compose/_target.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/compose
#   copying sklearn/compose/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/compose
#   copying sklearn/compose/_column_transformer.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/compose
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/compose/tests
#   copying sklearn/compose/tests/test_target.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/compose/tests
#   copying sklearn/compose/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/compose/tests
#   copying sklearn/compose/tests/test_column_transformer.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/compose/tests
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/covariance
#   copying sklearn/covariance/_graph_lasso.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/covariance
#   copying sklearn/covariance/_empirical_covariance.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/covariance
#   copying sklearn/covariance/graph_lasso_.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/covariance
#   copying sklearn/covariance/_shrunk_covariance.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/covariance
#   copying sklearn/covariance/_elliptic_envelope.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/covariance
#   copying sklearn/covariance/robust_covariance.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/covariance
#   copying sklearn/covariance/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/covariance
#   copying sklearn/covariance/elliptic_envelope.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/covariance
#   copying sklearn/covariance/_robust_covariance.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/covariance
#   copying sklearn/covariance/empirical_covariance_.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/covariance
#   copying sklearn/covariance/shrunk_covariance_.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/covariance
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/covariance/tests
#   copying sklearn/covariance/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/covariance/tests
#   copying sklearn/covariance/tests/test_covariance.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/covariance/tests
#   copying sklearn/covariance/tests/test_robust_covariance.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/covariance/tests
#   copying sklearn/covariance/tests/test_graphical_lasso.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/covariance/tests
#   copying sklearn/covariance/tests/test_elliptic_envelope.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/covariance/tests
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/cross_decomposition
#   copying sklearn/cross_decomposition/_cca.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cross_decomposition
#   copying sklearn/cross_decomposition/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cross_decomposition
#   copying sklearn/cross_decomposition/cca_.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cross_decomposition
#   copying sklearn/cross_decomposition/pls_.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cross_decomposition
#   copying sklearn/cross_decomposition/_pls.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cross_decomposition
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/cross_decomposition/tests
#   copying sklearn/cross_decomposition/tests/test_pls.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cross_decomposition/tests
#   copying sklearn/cross_decomposition/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cross_decomposition/tests
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/_base.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/_variance_threshold.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/rfe.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/_rfe.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/_from_model.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/mutual_info.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/_mutual_info.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/_univariate_selection.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/variance_threshold.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/univariate_selection.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/base.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection
#   copying sklearn/feature_selection/from_model.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection/tests
#   copying sklearn/feature_selection/tests/test_variance_threshold.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection/tests
#   copying sklearn/feature_selection/tests/test_rfe.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection/tests
#   copying sklearn/feature_selection/tests/test_from_model.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection/tests
#   copying sklearn/feature_selection/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection/tests
#   copying sklearn/feature_selection/tests/test_feature_select.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection/tests
#   copying sklearn/feature_selection/tests/test_chi2.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection/tests
#   copying sklearn/feature_selection/tests/test_base.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection/tests
#   copying sklearn/feature_selection/tests/test_mutual_info.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/feature_selection/tests
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/gaussian_process
#   copying sklearn/gaussian_process/gpr.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/gaussian_process
#   copying sklearn/gaussian_process/_gpc.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/gaussian_process
#   copying sklearn/gaussian_process/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/gaussian_process
#   copying sklearn/gaussian_process/gpc.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/gaussian_process
#   copying sklearn/gaussian_process/kernels.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/gaussian_process
#   copying sklearn/gaussian_process/_gpr.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/gaussian_process
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/gaussian_process/tests
#   copying sklearn/gaussian_process/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/gaussian_process/tests
#   copying sklearn/gaussian_process/tests/test_gpr.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/gaussian_process/tests
#   copying sklearn/gaussian_process/tests/test_kernels.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/gaussian_process/tests
#   copying sklearn/gaussian_process/tests/_mini_sequence_kernel.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/gaussian_process/tests
#   copying sklearn/gaussian_process/tests/test_gpc.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/gaussian_process/tests
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/impute
#   copying sklearn/impute/_base.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/impute
#   copying sklearn/impute/_knn.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/impute
#   copying sklearn/impute/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/impute
#   copying sklearn/impute/_iterative.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/impute
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/impute/tests
#   copying sklearn/impute/tests/test_common.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/impute/tests
#   copying sklearn/impute/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/impute/tests
#   copying sklearn/impute/tests/test_knn.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/impute/tests
#   copying sklearn/impute/tests/test_base.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/impute/tests
#   copying sklearn/impute/tests/test_impute.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/impute/tests
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/inspection
#   copying sklearn/inspection/_partial_dependence.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/inspection
#   copying sklearn/inspection/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/inspection
#   copying sklearn/inspection/_permutation_importance.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/inspection
#   copying sklearn/inspection/partial_dependence.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/inspection
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/inspection/tests
#   copying sklearn/inspection/tests/test_partial_dependence.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/inspection/tests
#   copying sklearn/inspection/tests/test_plot_partial_dependence.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/inspection/tests
#   copying sklearn/inspection/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/inspection/tests
#   copying sklearn/inspection/tests/test_permutation_importance.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/inspection/tests
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/mixture
#   copying sklearn/mixture/_base.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/mixture
#   copying sklearn/mixture/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/mixture
#   copying sklearn/mixture/bayesian_mixture.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/mixture
#   copying sklearn/mixture/gaussian_mixture.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/mixture
#   copying sklearn/mixture/_bayesian_mixture.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/mixture
#   copying sklearn/mixture/base.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/mixture
#   copying sklearn/mixture/_gaussian_mixture.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/mixture
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/mixture/tests
#   copying sklearn/mixture/tests/test_mixture.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/mixture/tests
#   copying sklearn/mixture/tests/test_bayesian_mixture.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/mixture/tests
#   copying sklearn/mixture/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/mixture/tests
#   copying sklearn/mixture/tests/test_gaussian_mixture.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/mixture/tests
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/model_selection
#   copying sklearn/model_selection/_search.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/model_selection
#   copying sklearn/model_selection/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/model_selection
#   copying sklearn/model_selection/_validation.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/model_selection
#   copying sklearn/model_selection/_split.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/model_selection
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/model_selection/tests
#   copying sklearn/model_selection/tests/test_split.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/model_selection/tests
#   copying sklearn/model_selection/tests/test_validation.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/model_selection/tests
#   copying sklearn/model_selection/tests/test_search.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/model_selection/tests
#   copying sklearn/model_selection/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/model_selection/tests
#   copying sklearn/model_selection/tests/common.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/model_selection/tests
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/neural_network
#   copying sklearn/neural_network/_base.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/neural_network
#   copying sklearn/neural_network/_rbm.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/neural_network
#   copying sklearn/neural_network/multilayer_perceptron.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/neural_network
#   copying sklearn/neural_network/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/neural_network
#   copying sklearn/neural_network/_stochastic_optimizers.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/neural_network
#   copying sklearn/neural_network/_multilayer_perceptron.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/neural_network
#   copying sklearn/neural_network/rbm.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/neural_network
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/neural_network/tests
#   copying sklearn/neural_network/tests/test_mlp.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/neural_network/tests
#   copying sklearn/neural_network/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/neural_network/tests
#   copying sklearn/neural_network/tests/test_rbm.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/neural_network/tests
#   copying sklearn/neural_network/tests/test_stochastic_optimizers.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/neural_network/tests
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/preprocessing
#   copying sklearn/preprocessing/_data.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/preprocessing
#   copying sklearn/preprocessing/_encoders.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/preprocessing
#   copying sklearn/preprocessing/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/preprocessing
#   copying sklearn/preprocessing/_discretization.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/preprocessing
#   copying sklearn/preprocessing/setup.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/preprocessing
#   copying sklearn/preprocessing/label.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/preprocessing
#   copying sklearn/preprocessing/_label.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/preprocessing
#   copying sklearn/preprocessing/data.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/preprocessing
#   copying sklearn/preprocessing/_function_transformer.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/preprocessing
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/preprocessing/tests
#   copying sklearn/preprocessing/tests/test_common.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/preprocessing/tests
#   copying sklearn/preprocessing/tests/test_label.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/preprocessing/tests
#   copying sklearn/preprocessing/tests/test_encoders.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/preprocessing/tests
#   copying sklearn/preprocessing/tests/test_function_transformer.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/preprocessing/tests
#   copying sklearn/preprocessing/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/preprocessing/tests
#   copying sklearn/preprocessing/tests/test_discretization.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/preprocessing/tests
#   copying sklearn/preprocessing/tests/test_data.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/preprocessing/tests
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/semi_supervised
#   copying sklearn/semi_supervised/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/semi_supervised
#   copying sklearn/semi_supervised/_label_propagation.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/semi_supervised
#   copying sklearn/semi_supervised/label_propagation.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/semi_supervised
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/semi_supervised/tests
#   copying sklearn/semi_supervised/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/semi_supervised/tests
#   copying sklearn/semi_supervised/tests/test_label_propagation.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/semi_supervised/tests
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/experimental
#   copying sklearn/experimental/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/experimental
#   copying sklearn/experimental/enable_hist_gradient_boosting.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/experimental
#   copying sklearn/experimental/enable_iterative_imputer.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/experimental
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/experimental/tests
#   copying sklearn/experimental/tests/test_enable_hist_gradient_boosting.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/experimental/tests
#   copying sklearn/experimental/tests/test_enable_iterative_imputer.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/experimental/tests
#   copying sklearn/experimental/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/experimental/tests
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble/_hist_gradient_boosting
#   copying sklearn/ensemble/_hist_gradient_boosting/predictor.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble/_hist_gradient_boosting
#   copying sklearn/ensemble/_hist_gradient_boosting/binning.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble/_hist_gradient_boosting
#   copying sklearn/ensemble/_hist_gradient_boosting/gradient_boosting.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble/_hist_gradient_boosting
#   copying sklearn/ensemble/_hist_gradient_boosting/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble/_hist_gradient_boosting
#   copying sklearn/ensemble/_hist_gradient_boosting/loss.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble/_hist_gradient_boosting
#   copying sklearn/ensemble/_hist_gradient_boosting/grower.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble/_hist_gradient_boosting
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble/_hist_gradient_boosting/tests
#   copying sklearn/ensemble/_hist_gradient_boosting/tests/test_grower.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble/_hist_gradient_boosting/tests
#   copying sklearn/ensemble/_hist_gradient_boosting/tests/test_binning.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble/_hist_gradient_boosting/tests
#   copying sklearn/ensemble/_hist_gradient_boosting/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble/_hist_gradient_boosting/tests
#   copying sklearn/ensemble/_hist_gradient_boosting/tests/test_splitting.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble/_hist_gradient_boosting/tests
#   copying sklearn/ensemble/_hist_gradient_boosting/tests/test_predictor.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble/_hist_gradient_boosting/tests
#   copying sklearn/ensemble/_hist_gradient_boosting/tests/test_loss.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble/_hist_gradient_boosting/tests
#   copying sklearn/ensemble/_hist_gradient_boosting/tests/test_gradient_boosting.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble/_hist_gradient_boosting/tests
#   copying sklearn/ensemble/_hist_gradient_boosting/tests/test_warm_start.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble/_hist_gradient_boosting/tests
#   copying sklearn/ensemble/_hist_gradient_boosting/tests/test_compare_lightgbm.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble/_hist_gradient_boosting/tests
#   copying sklearn/ensemble/_hist_gradient_boosting/tests/test_histogram.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble/_hist_gradient_boosting/tests
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/_agglomerative.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/bicluster.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/mean_shift_.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/_optics.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/_dbscan.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/_bicluster.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/hierarchical.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/_feature_agglomeration.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/k_means_.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/optics_.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/affinity_propagation_.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/_kmeans.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/_spectral.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/setup.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/_affinity_propagation.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/_birch.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/_mean_shift.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/spectral.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/birch.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   copying sklearn/cluster/dbscan_.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/test_mean_shift.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/test_k_means.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/test_feature_agglomeration.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/test_dbscan.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/test_birch.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/test_affinity_propagation.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/test_optics.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/test_hierarchical.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/common.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/test_bicluster.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster/tests
#   copying sklearn/cluster/tests/test_spectral.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/cluster/tests
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/_base.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/_samples_generator.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/_olivetti_faces.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/kddcup99.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/_kddcup99.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/olivetti_faces.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/_california_housing.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/svmlight_format.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/samples_generator.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/openml.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/covtype.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/_species_distributions.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/_covtype.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/lfw.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/rcv1.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/twenty_newsgroups.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/setup.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/_rcv1.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/_lfw.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/_svmlight_format_io.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/_twenty_newsgroups.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/_openml.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/species_distributions.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/california_housing.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   copying sklearn/datasets/base.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_california_housing.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_common.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_lfw.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_rcv1.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_kddcup99.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_covtype.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_svmlight_format.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_20news.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_samples_generator.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_openml.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_base.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets/tests
#   copying sklearn/datasets/tests/test_olivetti_faces.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/datasets/tests
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/_base.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/dict_learning.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/_factor_analysis.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/factor_analysis.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/_nmf.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/_sparse_pca.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/_kernel_pca.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/kernel_pca.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/online_lda.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/fastica_.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/online_lda_fast.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/incremental_pca.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/_incremental_pca.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/_fastica.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/sparse_pca.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/truncated_svd.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/_pca.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/setup.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/cdnmf_fast.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/pca.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/_truncated_svd.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/_dict_learning.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/nmf.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/base.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   copying sklearn/decomposition/_lda.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition
#   creating build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/decomposition/tests/test_dict_learning.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/decomposition/tests/test_fastica.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/decomposition/tests/test_truncated_svd.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/decomposition/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/decomposition/tests/test_nmf.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/decomposition/tests/test_online_lda.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/decomposition/tests/test_kernel_pca.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/decomposition/tests/test_sparse_pca.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/decomposition/tests/test_factor_analysis.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/decomposition/tests/test_incremental_pca.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/decomposition/tests/test_pca.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/decomposition/tests
#   copying sklearn/ensemble/_base.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble
#   copying sklearn/ensemble/_forest.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble
#   copying sklearn/ensemble/bagging.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble
#   copying sklearn/ensemble/_voting.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble
#   copying sklearn/ensemble/_bagging.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble
#   copying sklearn/ensemble/gradient_boosting.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble
#   copying sklearn/ensemble/weight_boosting.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble
#   copying sklearn/ensemble/_gb.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble
#   copying sklearn/ensemble/_weight_boosting.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble
#   copying sklearn/ensemble/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble
#   copying sklearn/ensemble/setup.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble
#   copying sklearn/ensemble/voting.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble
#   copying sklearn/ensemble/forest.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble
#   copying sklearn/ensemble/_gb_losses.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble
#   copying sklearn/ensemble/_iforest.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble
#   copying sklearn/ensemble/base.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble
#   copying sklearn/ensemble/partial_dependence.py -> build/lib.macosx-10.9-x86_64-3.9/sklearn/ensemble
# ...
#     C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64 -I/Users/ipsadm/opt/anaconda3/include -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64
#
#     compile options: '-c'
#     extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mavx512cd -mavx512vl -mavx512bw -mavx512dq -mavx512ifma -mavx512vbmi -Werror'
#     CCompilerOpt.cc_test_flags[999] : testing flags (-mavx512vnni)
#     C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64 -I/Users/ipsadm/opt/anaconda3/include -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64
#
#     compile options: '-c'
#     extra options: '-mavx512vnni'
#     CCompilerOpt.feature_test[1444] : testing feature 'AVX512_CLX' with flags (-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mavx512cd -mavx512vl -mavx512bw -mavx512dq -mavx512vnni)
#     C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64 -I/Users/ipsadm/opt/anaconda3/include -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64
#
#     compile options: '-c'
#     extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mavx512cd -mavx512vl -mavx512bw -mavx512dq -mavx512vnni -Werror'
#     CCompilerOpt.cc_test_flags[999] : testing flags (-mavx512vbmi2 -mavx512bitalg -mavx512vpopcntdq)
#     C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64 -I/Users/ipsadm/opt/anaconda3/include -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64
#
#     compile options: '-c'
#     extra options: '-mavx512vbmi2 -mavx512bitalg -mavx512vpopcntdq'
#     CCompilerOpt.feature_test[1444] : testing feature 'AVX512_ICL' with flags (-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mavx512cd -mavx512vl -mavx512bw -mavx512dq -mavx512vnni -mavx512ifma -mavx512vbmi -mavx512vbmi2 -mavx512bitalg -mavx512vpopcntdq)
#     C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64 -I/Users/ipsadm/opt/anaconda3/include -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64
#
#     compile options: '-c'
#     extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mavx512cd -mavx512vl -mavx512bw -mavx512dq -mavx512vnni -mavx512ifma -mavx512vbmi -mavx512vbmi2 -mavx512bitalg -mavx512vpopcntdq -Werror'
#     CCompilerOpt.cc_test_flags[999] : testing flags (-mavx512er -mavx512pf)
#     C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64 -I/Users/ipsadm/opt/anaconda3/include -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64
#
#     compile options: '-c'
#     extra options: '-mavx512er -mavx512pf'
#     CCompilerOpt.feature_test[1444] : testing feature 'AVX512_KNL' with flags (-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mavx512cd -mavx512er -mavx512pf)
#     C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64 -I/Users/ipsadm/opt/anaconda3/include -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64
#
#     compile options: '-c'
#     extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mavx512cd -mavx512er -mavx512pf -Werror'
#     CCompilerOpt.cc_test_flags[999] : testing flags (-mavx5124fmaps -mavx5124vnniw -mavx512vpopcntdq)
#     C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64 -I/Users/ipsadm/opt/anaconda3/include -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64
#
#     compile options: '-c'
#     extra options: '-mavx5124fmaps -mavx5124vnniw -mavx512vpopcntdq'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[711] : Command (clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64 -I/Users/ipsadm/opt/anaconda3/include -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64 -c /Users/ipsadm/opt/anaconda3/lib/python3.9/site-packages/numpy/distutils/checks/test_flags.c -o /var/folders/x0/50gt0r5j31xgwlz771y2q_340000gp/T/tmpe88ozfwp/Users/ipsadm/opt/anaconda3/lib/python3.9/site-packages/numpy/distutils/checks/test_flags.o -MMD -MF /var/folders/x0/50gt0r5j31xgwlz771y2q_340000gp/T/tmpe88ozfwp/Users/ipsadm/opt/anaconda3/lib/python3.9/site-packages/numpy/distutils/checks/test_flags.o.d -mavx5124fmaps -mavx5124vnniw -mavx512vpopcntdq) failed with exit status 1 output ->
#     clang: error: unknown argument: '-mavx5124fmaps'
#     clang: error: unknown argument: '-mavx5124vnniw'
#
#     CCompilerOpt.cc_test_flags[1003] : testing failed
#     CCompilerOpt.feature_test[1444] : testing feature 'AVX512_KNM' with flags (-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mavx512cd -mavx512er -mavx512pf)
#     C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64 -I/Users/ipsadm/opt/anaconda3/include -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64
#
#     compile options: '-c'
#     extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mavx512cd -mavx512er -mavx512pf -Werror'
#     CCompilerOpt.dist_test[576] : CCompilerOpt._dist_test_spawn[711] : Command (clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64 -I/Users/ipsadm/opt/anaconda3/include -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64 -c /Users/ipsadm/opt/anaconda3/lib/python3.9/site-packages/numpy/distutils/checks/cpu_avx512_knm.c -o /var/folders/x0/50gt0r5j31xgwlz771y2q_340000gp/T/tmpe88ozfwp/Users/ipsadm/opt/anaconda3/lib/python3.9/site-packages/numpy/distutils/checks/cpu_avx512_knm.o -MMD -MF /var/folders/x0/50gt0r5j31xgwlz771y2q_340000gp/T/tmpe88ozfwp/Users/ipsadm/opt/anaconda3/lib/python3.9/site-packages/numpy/distutils/checks/cpu_avx512_knm.o.d -msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mavx512cd -mavx512er -mavx512pf -Werror) failed with exit status 1 output ->
#     /Users/ipsadm/opt/anaconda3/lib/python3.9/site-packages/numpy/distutils/checks/cpu_avx512_knm.c:9:9: error: implicit declaration of function '_mm512_4fmadd_ps' is invalid in C99 [-Werror,-Wimplicit-function-declaration]
#         b = _mm512_4fmadd_ps(b, b, b, b, b, NULL);
#             ^
#     /Users/ipsadm/opt/anaconda3/lib/python3.9/site-packages/numpy/distutils/checks/cpu_avx512_knm.c:9:9: note: did you mean '_mm512_fmadd_ps'?
#     /Library/Developer/CommandLineTools/usr/lib/clang/13.0.0/include/avx512fintrin.h:2716:1: note: '_mm512_fmadd_ps' declared here
#     _mm512_fmadd_ps(__m512 __A, __m512 __B, __m512 __C)
#     ^
#     /Users/ipsadm/opt/anaconda3/lib/python3.9/site-packages/numpy/distutils/checks/cpu_avx512_knm.c:9:7: error: assigning to '__m512' (vector of 16 'float' values) from incompatible type 'int'
#         b = _mm512_4fmadd_ps(b, b, b, b, b, NULL);
#           ^ ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     /Users/ipsadm/opt/anaconda3/lib/python3.9/site-packages/numpy/distutils/checks/cpu_avx512_knm.c:11:9: error: implicit declaration of function '_mm512_4dpwssd_epi32' is invalid in C99 [-Werror,-Wimplicit-function-declaration]
#         a = _mm512_4dpwssd_epi32(a, a, a, a, a, NULL);
#             ^
#     /Users/ipsadm/opt/anaconda3/lib/python3.9/site-packages/numpy/distutils/checks/cpu_avx512_knm.c:11:9: note: did you mean '_mm512_dpwssd_epi32'?
#     /Library/Developer/CommandLineTools/usr/lib/clang/13.0.0/include/avx512vnniintrin.h:68:1: note: '_mm512_dpwssd_epi32' declared here
#     _mm512_dpwssd_epi32(__m512i __S, __m512i __A, __m512i __B)
#     ^
#     /Users/ipsadm/opt/anaconda3/lib/python3.9/site-packages/numpy/distutils/checks/cpu_avx512_knm.c:11:7: error: assigning to '__m512i' (vector of 8 'long long' values) from incompatible type 'int'
#         a = _mm512_4dpwssd_epi32(a, a, a, a, a, NULL);
#           ^ ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     4 errors generated.
#
#     CCompilerOpt.feature_test[1458] : testing failed
#     CCompilerOpt.__init__[1695] : skip features (SSE3 SSE2 SSE) since its part of baseline
#     CCompilerOpt.__init__[1699] : initialize targets groups
#     CCompilerOpt.__init__[1701] : parse target group simd_test
#     CCompilerOpt._parse_target_tokens[1910] : skip targets (NEON ASIMD VSX2 VSX3 VSX XOP FMA4) not part of baseline or dispatch-able features
#     CCompilerOpt._parse_policy_not_keepbase[2022] : skip baseline features (SSE2)
#     CCompilerOpt.generate_dispatch_header[2236] : generate CPU dispatch header: (build/src.macosx-10.9-x86_64-3.9/numpy/distutils/include/npy_cpu_dispatch_config.h)
#     CCompilerOpt.generate_dispatch_header[2245] : dispatch header dir build/src.macosx-10.9-x86_64-3.9/numpy/distutils/include does not exist, creating it
#     CCompilerOpt.feature_extra_checks[1519] : Testing extra checks for feature 'AVX512F' (AVX512F_REDUCE)
#     C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64 -I/Users/ipsadm/opt/anaconda3/include -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64
#
#     compile options: '-c'
#     extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -Werror'
#     CCompilerOpt.feature_extra_checks[1519] : Testing extra checks for feature 'AVX512_SKX' (AVX512BW_MASK AVX512DQ_MASK)
#     C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64 -I/Users/ipsadm/opt/anaconda3/include -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64
#
#     compile options: '-c'
#     extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mavx512cd -mavx512vl -mavx512bw -mavx512dq -Werror'
#     C compiler: clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64 -I/Users/ipsadm/opt/anaconda3/include -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64
#
#     compile options: '-c'
#     extra options: '-msse -msse2 -msse3 -mssse3 -msse4.1 -mpopcnt -msse4.2 -mavx -mf16c -mfma -mavx2 -mavx512f -mavx512cd -mavx512vl -mavx512bw -mavx512dq -Werror'
#     Detected changes on compiler optimizations, force rebuilding
#     building 'libsvm-skl' library
#     compiling C++ sources
#     C compiler: clang++ -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64 -I/Users/ipsadm/opt/anaconda3/include -fPIC -O2 -isystem /Users/ipsadm/opt/anaconda3/include -arch x86_64
#
#     creating build/temp.macosx-10.9-x86_64-3.9
#     creating build/temp.macosx-10.9-x86_64-3.9/sklearn
#     creating build/temp.macosx-10.9-x86_64-3.9/sklearn/svm
#     creating build/temp.macosx-10.9-x86_64-3.9/sklearn/svm/src
#     creating build/temp.macosx-10.9-x86_64-3.9/sklearn/svm/src/libsvm
#     compile options: '-I/Users/ipsadm/opt/anaconda3/lib/python3.9/site-packages/numpy/core/include -Ibuild/src.macosx-10.9-x86_64-3.9/numpy/distutils/include -c'
#     extra options: '-msse -msse2 -msse3'
#     clang++: sklearn/svm/src/libsvm/libsvm_template.cpp
#     In file included from sklearn/svm/src/libsvm/libsvm_template.cpp:6:
#     sklearn/svm/src/libsvm/svm.cpp:3116:11: warning: conversion from string literal to 'char *' is deprecated [-Wc++11-compat-deprecated-writable-strings]
#                             msg =  "Invalid input - all samples have zero or negative weights.";
#                                    ^
#     sklearn/svm/src/libsvm/svm.cpp:3131:11: warning: conversion from string literal to 'char *' is deprecated [-Wc++11-compat-deprecated-writable-strings]
#                                     msg = "Invalid input - all samples with positive weights have the same label.";
#                                           ^
#     In file included from sklearn/svm/src/libsvm/libsvm_template.cpp:8:
#     sklearn/svm/src/libsvm/svm.cpp:3116:11: warning: conversion from string literal to 'char *' is deprecated [-Wc++11-compat-deprecated-writable-strings]
#                             msg =  "Invalid input - all samples have zero or negative weights.";
#                                    ^
#     sklearn/svm/src/libsvm/svm.cpp:3131:11: warning: conversion from string literal to 'char *' is deprecated [-Wc++11-compat-deprecated-writable-strings]
#                                     msg = "Invalid input - all samples with positive weights have the same label.";
#                                           ^
#     4 warnings generated.
#     llvm-ar: adding 1 object files to build/temp.macosx-10.9-x86_64-3.9/liblibsvm-skl.a
#     error: Command "/opt/concourse/worker/volumes/live/c1a1a6ef-e724-4ad9-52a7-d6d68451dacb/volume/python-split_1631807121927/_build_env/bin/llvm-ar rcs build/temp.macosx-10.9-x86_64-3.9/liblibsvm-skl.a build/temp.macosx-10.9-x86_64-3.9/sklearn/svm/src/libsvm/libsvm_template.o" failed with exit status 127
#
#     ########### CLIB COMPILER OPTIMIZATION ###########
#     Platform      :
#       Architecture: x64
#       Compiler    : clang
#
#     CPU baseline  :
#       Requested   : 'min'
#       Enabled     : SSE SSE2 SSE3
#       Flags       : -msse -msse2 -msse3
#       Extra checks: none
#
#     CPU dispatch  :
#       Requested   : 'max -xop -fma4'
#       Enabled     : SSSE3 SSE41 POPCNT SSE42 AVX F16C FMA3 AVX2 AVX512F AVX512CD AVX512_KNL AVX512_SKX AVX512_CLX AVX512_CNL AVX512_ICL
#       Generated   : none
#     CCompilerOpt._cache_write[796] : write cache to path -> /private/var/folders/x0/50gt0r5j31xgwlz771y2q_340000gp/T/pip-install-fjvv8j34/scikit-learn_3debc9675a89421188c35cad03f9b911/build/temp.macosx-10.9-x86_64-3.9/ccompiler_opt_cache_clib.py
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /Users/ipsadm/opt/anaconda3/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/x0/50gt0r5j31xgwlz771y2q_340000gp/T/pip-install-fjvv8j34/scikit-learn_3debc9675a89421188c35cad03f9b911/setup.py'"'"'; __file__='"'"'/private/var/folders/x0/50gt0r5j31xgwlz771y2q_340000gp/T/pip-install-fjvv8j34/scikit-learn_3debc9675a89421188c35cad03f9b911/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/x0/50gt0r5j31xgwlz771y2q_340000gp/T/pip-record-pbyl3yrj/install-record.txt --single-version-externally-managed --user --prefix= --compile --install-headers /Users/R355-W-12-Stud/.local/include/python3.9/scikit-learn Check the logs for full command output.

# %%
from  sklearn.feature_extraction.text import CountVectorizer

encoder = CountVectorizer(binary=True)
encoded_data = encoder.fit_transform(query_data)
encoded_queries = encoder.transform(QUERIES)
list(encoder.vocabulary_)[:3]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/x0/50gt0r5j31xgwlz771y2q_340000gp/T/ipykernel_18710/4137195061.py in <module>
#       2
#       3 encoder = CountVectorizer(binary=True)
# ----> 4 encoded_data = encoder.fit_transform(query_data)
#       5 encoded_queries = encoder.transform(QUERIES)
#       6 list(encoder.vocabulary_)[:3]
#
# /Users/ipsadm/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1200         max_features = self.max_features
#    1201
# -> 1202         vocabulary, X = self._count_vocab(raw_documents,
#    1203                                           self.fixed_vocabulary_)
#    1204
#
# /Users/ipsadm/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1131             vocabulary = dict(vocabulary)
#    1132             if not vocabulary:
# -> 1133                 raise ValueError("empty vocabulary; perhaps the documents only"
#    1134                                  " contain stop words")
#    1135
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %% [markdown]
# Let's look at the representation of the first sentence

# %%
id2term = {idx: term for term, idx in encoder.vocabulary_.items()}
non_zero_values_ids = encoded_data[0].nonzero()[1]

terms = [id2term[idx] for idx in non_zero_values_ids]
terms

# %% [markdown]
# It's fine.
#
# ## Task 0
#
# Now for each query from `QUERIES` let's find the nearest document from `query_data` according to the Jaccard similarity index. There are more effictive solutions to do it, but your task is to realize the algorithm computing the Jaccard index and then apply it to our data.

# %%
import numpy as np 

def jaccard_sim(vector_a: np.array, vector_b: np.array) -> float:
  """
    Similarity or Jaccard similarity index: the ratio of the intersection cardinality to the union cardinality
  """
  # your code here
  
  return
#Check that the function works correctly
assert jaccard_sim(np.array([1, 0, 1, 0, 1]), np.array([0, 1, 1, 1, 1])) == 0.4

# %% [markdown]
# ## Task 1
# Now using the code below find the most similar documents for each query.

# %%
for q_id, query in enumerate(encoded_queries):
  # bring to the required datatype
  query = query.todense().A1
  docs = [doc.todense().A1 for doc in encoded_data]
  # calculate the Jaccard index
  id2doc2similarity = [(doc_id, doc, jaccard_sim(query, doc)) for doc_id, doc in enumerate(docs)]
  # sort according to it
  closest = sorted(id2doc2similarity, key=lambda x: x[2], reverse=True)
  
  print("Q: %s\nFOUND:" % QUERIES[q_id])
  # output 3 most similar documents for each query
  for closest_id, _, sim in closest[:3]:
    print("    %d\t%.2f\t%s" %(closest_id, sim, query_data[closest_id]))

# %% [markdown]
# We see that some texts intersecting with the query only in insignificant terms have a high Jaccard index (that is our ranking function).
#
# # VSM
#
# Now we are going to do similar calculations, but using tf-idf and cosine distance. To practice we make everything "manually", but in "real life" it's better to use existing effective solutions, e.g., cosine distance from scipy library.

# %%
from  sklearn.feature_extraction.text import TfidfVectorizer

# Advice: we highly recommend to check what tf-idf vectorizer
# is able to do, and change its parameters

tfidf_encoder = TfidfVectorizer()
tfidf_encoded_data = tfidf_encoder.fit_transform(query_data)
tfidf_encoded_queries = tfidf_encoder.transform(QUERIES)

list(tfidf_encoder.vocabulary_)[:3]

# %% [markdown]
# ## Task 2
# Realize the cosine distance computation

# %%
import numpy as np 

def cosine_distance(vector_a: np.array, vector_b: np.array) -> float:
  """
    Cosine distance is 1 minus the ratio of the dot product 
    and the product of L2-norm (hint: there are such norms in numpy)
  """
  # your code here

  return  
#Check that the function is working correctly
assert cosine_distance(np.array([1, 0, 1, 1, 1]), np.array([0, 0, 1, 0, 0])) == 0.5

# %% [markdown]
# Now let's find the nearset documents to the query according to the cosine distance between the document vector and the query representation

# %%
for q_id, query in enumerate(tfidf_encoded_queries):
  
  # bring to the required datatype
  query = query.todense().A1
  docs = [doc.todense().A1 for doc in tfidf_encoded_data]
  # Cosine distance
  id2doc2similarity = [(doc_id, doc, cosine_distance(query, doc)) \
                       for doc_id, doc in enumerate(docs)]
  # sort according to it
  closest = sorted(id2doc2similarity, key=lambda x: x[2], reverse=False)
  
  print("Q: %s\nFOUND:" % QUERIES[q_id])
  
  for closest_id, _, sim in closest[:3]:
    print("    %d\t%.2f\t%s" %(closest_id, sim, query_data[closest_id]))
